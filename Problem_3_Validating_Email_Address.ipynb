# %% [markdown]
# <a href="https://colab.research.google.com/github/Quirt455/samplepythonactivities/blob/main/Problem_3_Validating_Email_Address.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
    email = input("Enter your email :) ")

    if "@" in email and "." in email:
        print("Email accepted, good boy:", email)
        break
    else:
        print("Invalid email! try again and make it right >:(")
        break
