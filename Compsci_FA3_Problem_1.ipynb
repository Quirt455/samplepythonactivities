# %% [markdown]
# <a href="https://colab.research.google.com/github/Quirt455/samplepythonactivities/blob/main/Compsci_FA3_Problem_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#code for part 2
credit_score = float(input("Enter credit score: "))
income = float(input("Enter annual income: "))
years_at_job = float(input("Enter years at current job: "))

#check if credit, income and years at job are valid amounts.
if credit_score >= 700 and income >= 30000 and years_at_job >= 2:
    print("Loan Approved")
else:
    print("Loan Denied")
