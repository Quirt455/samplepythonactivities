# %% [markdown]
# <a href="https://colab.research.google.com/github/Quirt455/samplepythonactivities/blob/main/Problem_2_Validating_Phone_Number_Format.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
    number = input("Enter your phone number: ")

    # Checks if the number follows the correct format
    if (len(number) == 13 and
        number[0] == "0" and
        number[1] == "9" and
        number[4] == "-" and
        number[8] == "-" and
        number[:4].isdigit() and # Checks if all the Xs are numbers
        number[5:8].isdigit() and
        number[9:].isdigit()):

        print("Phone number accepted, good boy:", number)
        break
    else:
        print("Invalid format! Please enter your phone number in 09XX-XXX-XXXX format >:(")
        break
# Out:
# Enter your phone number: 09123-456-789
# Invalid format! Please enter your phone number in 09XX-XXX-XXXX format >:(
