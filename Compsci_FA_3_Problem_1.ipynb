# %% [markdown]
# <a href="https://colab.research.google.com/github/Quirt455/samplepythonactivities/blob/main/Compsci_FA_3_Problem_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Code for part 1
password = input("Enter your password: ")

# Check if password is 8 to 15 characters
if len(password) >= 8 and len(password) <= 15:
    print("Password is valid.")
else:
    print("Password is too long/too short, try again.")
# Out:
# Enter your password: strongPass12
# Password is valid.
